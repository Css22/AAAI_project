# %%
import numpy as np
import matplotlib.pyplot as plt
path = '/data/zbw/course/AAAI/project/work/processed_data/test/6062.npy'
path = '/data/zbw/course/AAAI/project/work/processed_data/train/0/1.npy'
data = np.load(path)
for i in range(0, 10):
    channel_to_visualize = i
    channel_data = data[channel_to_visualize]
    plt.imshow(channel_data, cmap='gray')  
    plt.colorbar()  # 添加颜色条（可选）
    plt.show()
